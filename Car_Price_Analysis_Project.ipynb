# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/daTA.csv")

# %% [markdown]
# **Shape Inspection**

# %%
a =df.shape #attribute
print (f'the shape of the data is  row {a[0]} and colum {a[1]}')
# Out:
# the shape of the data is  row 301 and colum 9

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.Car_Name.unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
df.Car_Name.value_counts()
# Out:
# Car_Name
# city                  26
# corolla altis         16
# verna                 14
# fortuner              11
# brio                  10
#                       ..
# Honda Activa 125       1
# Hero Hunk              1
# Hero  Ignitor Disc     1
# Hero  CBZ Xtreme       1
# Bajaj  ct 100          1
# Name: count, Length: 98, dtype: int64

# %%
a= pd.Timestamp.now()
print(a)
current_year = 2025
df['Car_age'] = current_year - df['Year']
# Out:
# 2025-10-28 14:07:04.641067

# %%
df['depreciation']= df['Present_Price'] - df['Selling_Price']
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_age  depreciation
# 0      Dealer       Manual      0       11          2.24
# 1      Dealer       Manual      0       12          4.79
# 2      Dealer       Manual      0        8          2.60
# 3      Dealer       Manual      0       14          1.30
# 4      Dealer       Manual      0       11          2.27

# %%
df.rename(columns={'Car_Name':'Brand',
                        'Present_Price':'Price'
                        },inplace =True)

# %%
df.head()
# Out:
#      Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1      sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2     ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3  wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4    swift  2014           4.60   6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car_age  depreciation
# 0       Manual      0       11          2.24
# 1       Manual      0       12          4.79
# 2       Manual      0        8          2.60
# 3       Manual      0       14          1.30
# 4       Manual      0       11          2.27

# %%
Price_array = df['Price'].values
price_segment = np.where(Price_array>20, 'Luxuary ', 'standard')
df['segment'] = price_segment
df.head()
# Out:
#      Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1      sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2     ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3  wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4    swift  2014           4.60   6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car_age  depreciation   segment
# 0       Manual      0       11          2.24  standard
# 1       Manual      0       12          4.79  standard
# 2       Manual      0        8          2.60  standard
# 3       Manual      0       14          1.30  standard
# 4       Manual      0       11          2.27  standard

# %%
price_array = df['Price'].values
price_segment= np.where(price_array >10 ,'Luxuary', 'standard')
df['segment'] = price_segment
df.head()
# Out:
#      Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1      sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2     ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3  wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4    swift  2014           4.60   6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car_age  depreciation   segment
# 0       Manual      0       11          2.24  standard
# 1       Manual      0       12          4.79  standard
# 2       Manual      0        8          2.60  standard
# 3       Manual      0       14          1.30  standard
# 4       Manual      0       11          2.27  standard

# %%
df.describe().transpose()
# Out:
#                count          mean           std      min       25%       50%  \
# Year           301.0   2013.627907      2.891554  2003.00   2012.00   2014.00
# Selling_Price  301.0      4.661296      5.082812     0.10      0.90      3.60
# Price          301.0      7.628472      8.644115     0.32      1.20      6.40
# Kms_Driven     301.0  36947.205980  38886.883882   500.00  15000.00  32000.00
# Owner          301.0      0.043189      0.247915     0.00      0.00      0.00
# Car_age        301.0     11.372093      2.891554     7.00      9.00     11.00
# depreciation   301.0      2.967176      4.828771     0.03      0.39      1.64
#
#                     75%       max
# Year            2016.00    2018.0
# Selling_Price      6.00      35.0
# Price              9.90      92.6
# Kms_Driven     48767.00  500000.0
# Owner              0.00       3.0
# Car_age           13.00      22.0
# depreciation       3.35      57.6

# %%
df.describe(include= 'object').transpose()
# Out:
#              count unique       top freq
# Brand          301     98      city   26
# Fuel_Type      301      3    Petrol  239
# Seller_Type    301      2    Dealer  195
# Transmission   301      2    Manual  261
# segment        301      2  standard  235

# %%
sns.countplot(x='Fuel_Type', data= df)
plt.title('Fuel Type')
plt.show()

# %%
df.columns
# Out:
# Index(['Brand', 'Year', 'Selling_Price', 'Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_age', 'depreciation',
#        'segment'],
#       dtype='object')

# %%
sns.countplot(x= 'Seller_Type', data= df)
plt.grid(True)
plt.show()

# %%
sns.countplot(x= 'Transmission' ,data= df)
plt.title('Transmission distribution')
plt.show()

# %%
sns.countplot(x= 'Transmission' ,data= df)
plt.title('Transmission distribution')
plt.show()

# %%
sns.countplot(data= df , hue='Transmission' , x='Year')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x='Price' ,y='Selling_Price' , data=df)
plt.title('present Price vs Selling Price')
plt.show()

# %%
sns.lineplot(y='Selling_Price',x='Car_age',data= df)
plt.show()

# %%
sns.barplot(x='Fuel_Type',y='Selling_Price',data= df)
plt.show()

# %%
df.columns
# Out:
# Index(['Brand', 'Year', 'Selling_Price', 'Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_age', 'depreciation',
#        'segment'],
#       dtype='object')

# %%
summary = df.groupby('Fuel_Type')[['Selling_Price','depreciation','Kms_Driven']].mean()
summary
# Out:
#            Selling_Price  depreciation    Kms_Driven
# Fuel_Type
# CNG             3.100000      3.315000  42749.000000
# Diesel         10.278500      5.536000  50369.916667
# Petrol          3.264184      2.319372  33528.937238

# %%
df['depreciation_%'] = (df['depreciation']/df['Price'])*100
df.head()
# Out:
#      Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1      sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2     ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3  wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4    swift  2014           4.60   6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car_age  depreciation   segment  depreciation_%
# 0       Manual      0       11          2.24  standard       40.071556
# 1       Manual      0       12          4.79  standard       50.209644
# 2       Manual      0        8          2.60  standard       26.395939
# 3       Manual      0       14          1.30  standard       31.325301
# 4       Manual      0       11          2.27  standard       33.042213
